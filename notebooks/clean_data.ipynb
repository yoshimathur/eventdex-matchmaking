# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./data/Test MM  Seller data from wbenc.csv')

# %%
for col in df.columns: 
    null_count = df[col].isna().sum()
    print(col, null_count)
# Out:
# Prefix 519
# First Name 0
# Last Name 0
# Primary Email 0
# Secondary Email 0
# Company 0
# DBA 443
# Job Title 1
# Mobile Number 0
# Primary Business Category 2
# Secondary Business Category 470
# Number of Employees 1
# Business Established Date 0
# BBB Number 0
# Business DUNS Number 0
# RPO 373
# Distribution Country 409
# Manufactures Country 393
# Ethnicity 14
# References 1 51
# References 2 56
# Scope of Work 1 53
# Scope of Work 2 60
# Revenue 47
# Business Tax Id 0
# Website URL 2
# Business Description 46
# Work Address 1 9
# Work Address 2 426
# Work city 0
# Work State 2
# Work Country 2
# Work Zip Code 3
# Work Country.1 3
# Geographical Region 59
# NAICS Code 1 2
# NAICS Code 2 274
# NAICS Code 3 328
# NAICS Code 4 378
# NAICS Code 5 413
# NAICS Code 6 537
# NAICS Code 7 549
# NAICS Code 8 563
# NAICS Code 9 568
# Commodities 106
# Commodities.1 202
# Commodities.2 244
# Commodities.3 292
# Commodities.4 340
# Keywords 1
# Year in business 47
# Business Structure 211
# Fax Number 0
# Non WBENC Awards 324
# Outside Facilities 72

# %%
# DBA --> mostly null
# Join DBA to Company [DBA: _] seperated
# Drop DBA 
for i in range(len(df['Company'])):
    if type(df['DBA'][i]) == str: 
        updated_company = df['Company'][i] + f" [DBA: {df['DBA'][i]}]"
        df.iloc[i, df.columns.get_loc('Company')] = updated_company
df.drop('DBA', axis=1, inplace=True)

# %%
# merge Business Category
df['Business Category'] = df.apply(
    lambda row: ', '.join(filter(pd.notna, [row['Primary Business Category'], row['Secondary Business Category']])),
    axis=1
)
df.drop(['Primary Business Category', 'Secondary Business Category'], axis=1, inplace=True)

# %%
# merge NAICS Codes  
naics_code_columns = [f'NAICS Code {i}' for i in range(1, 10)]
df['NAICS Codes'] = df[naics_code_columns].apply(lambda row: ', '.join(row.dropna().astype(str)), axis=1)
df.drop(columns=naics_code_columns, axis=1, inplace=True)

# %%
# merge commodities
commodities_columns = [f'Commodities.{i}' for i in range(1, 5)]
commodities_columns.append('Commodities')
commodities = df[commodities_columns].apply(lambda row: ', '.join(row.dropna().astype(str)), axis=1)
df.drop(commodities_columns, axis=1, inplace=True)
df['Commodities'] = commodities

# %%
# merge location data 
loc_columns = ['Work Address 1', 'Work city', 'Work State', 'Work Country', 'Work Zip Code']
df['Location'] = df[loc_columns].apply(lambda row: ', '.join(row.dropna().astype(str)), axis=1)
loc_columns.append('Work Address 2')
loc_columns.append('Work Country.1')
df.drop(loc_columns, axis=1, inplace=True)

# %%
# merge references
df['References'] = df.apply(
    lambda row: ', '.join(filter(pd.notna, [row['References 1'], row['References 2']])),
    axis=1
)
df.drop(['References 1', 'References 2'], axis=1, inplace=True)

# %%
# merge scope of work
df['Scope of Work'] = df.apply(
    lambda row: ', '.join(filter(pd.notna, [row['Scope of Work 1'], row['Scope of Work 2']])),
    axis=1
)
df.drop(['Scope of Work 1', 'Scope of Work 2'], axis=1, inplace=True)

# %%
#drop year in business --> use business established date (no null values)
df.drop('Year in business', axis=1, inplace=True)

# %%
df.head(10)
# Out:
#   Prefix    First Name      Last Name                          Primary Email  \
# 0    Ms.          Maia        Ballard       pandcsupplies17@noemailyahoo.com
# 1   Mrs.           Kim         Thiara             kim17@noemailacetronic.com
# 2    Ms.          Lise         Deziel              ldeziel17@noemailcorde.ca
# 3    NaN       Fabiola  Soler Bonilla         fsoler17@noemailcrglobalaw.com
# 4    NaN       Adriana  Rojas Pacheco       adriana.r17@noemaildipsafood.com
# 5    NaN       Kristin      Macmillan       kristin17@noemailimprintplus.com
# 6    NaN  Maria Teresa         Cepeda        direccion17@noemailism-foil.com
# 7    NaN          Ilse    Hoffmaister  ihoffmaister17@noemailnutrisnacks.net
# 8    NaN       Carolyn        Pearson     carolyn17@noemailmaiden-voyage.com
# 9    NaN       Allison       Pinheiro      tamires.rocha17@noemailmcm.br.com
#
#                          Secondary Email  \
# 0       pandcsupplies17@noemailyahoo.com
# 1             kim17@noemailacetronic.com
# 2              ldeziel17@noemailcorde.ca
# 3         fsoler17@noemailcrglobalaw.com
# 4       adriana.r17@noemaildipsafood.com
# 5       kristin17@noemailimprintplus.com
# 6        direccion17@noemailism-foil.com
# 7  ihoffmaister17@noemailnutrisnacks.net
# 8     carolyn17@noemailmaiden-voyage.com
# 9      tamires.rocha17@noemailmcm.br.com
#
#                                              Company  \
# 0               P and C Supplies [DBA: P N C Supply]
# 1                      AceTronic Industrial Controls
# 2                               Corde Electrique inc
# 3                     Costa Rica Global Law Inc S.A.
# 4  DIPSA Food Energy Representaciones S.A.S. [DBA...
# 5            Illen Products Ltd. [DBA: Imprint Plus]
# 6            Imaging Supplies De Mexico S.A. DE C.V.
# 7            Industria Mafam S.A. [DBA: Nutrisnacks]
# 8                                  Maiden-Voyage.com
# 9                               MCM Brand Experience
#
#                                        Job Title Mobile Number  \
# 0                                          Owner  813-830-3560
# 1                                      President  813-830-3561
# 2  President|CEO|Founder|Owner|Managing Director  813-830-3562
# 3            CEO|Founder|Owner|Managing Director  813-830-3563
# 4                                       Director  813-830-3564
# 5                                      President  813-830-3565
# 6                               Managing Partner  813-830-3566
# 7                                President & CEO  813-830-3567
# 8                                  Founder & CEO  813-830-3568
# 9                                      President  813-830-3569
#
#    Number of Employees Business Established Date  ...   Business Structure  \
# 0                 10.0                  4/3/1990  ...          Corporation
# 1                 15.0                  4/3/1991  ...          Corporation
# 2                 48.0                  4/3/1992  ...      Sole Proprietor
# 3                  5.0                  4/3/1993  ...          Corporation
# 4                150.0                  4/3/1994  ...          Corporation
# 5                 60.0                  4/3/1995  ...          Corporation
# 6                100.0                  4/3/1996  ...          Corporation
# 7                 65.0                  4/3/1997  ...  General Partnership
# 8                  5.0                  4/3/1998  ...          Corporation
# 9                 40.0                  4/3/1999  ...  Sole Proprietorship
#
#      Fax Number                                   Non WBENC Awards  \
# 0  985-875-1001                                               NONE
# 1  985-875-1002                                                add
# 2  985-875-1003  RFAQ Mid-size enterprise 2015, women business ...
# 3  985-875-1004                                                NaN
# 4  985-875-1005                                                NaN
# 5  985-875-1006      2015 Women to Watch, SGIA Golden Image Awards
# 6  985-875-1007                                                NaN
# 7  985-875-1008                                                NaN
# 8  985-875-1009                                                NaN
# 9  985-875-1010                                                NaN
#
#         Outside Facilities                                 Business Category  \
# 0                       no                                   Wholesale Trade
# 1                      Yes                                     Manufacturing
# 2              Yes, Canada                                     Manufacturing
# 3  Costa Rica and USA (FL)  Professional, Scientific, and Technical Services
# 4                      YES                                   Wholesale Trade
# 5                   Canada                                     Manufacturing
# 6                   Mexico                                     Manufacturing
# 7               Costa Rica
# 8           United Kingdom   Professional, Scientific and Technical Services
# 9                      YES   Professional, Scientific and Technical Services
#
#                                          NAICS Codes  \
# 0  423510 Metal Service Centers and Other Metal M...
# 1  335999 All Other Miscellaneous Electrical Equi...
# 2  335999 All Other Miscellaneous Electrical Equi...
# 3                          541110 Offices of Lawyers
# 4  311919 Other Snack Food Manufacturing, 445299 ...
# 5    326199 All Other Plastics Product Manufacturing
# 6  331419 Primary Smelting and Refining of Nonfer...
# 7
# 8  541690 Other Scientific and Technical Consulti...
# 9                        541810 Advertising Agencies
#
#                                          Commodities  \
# 0  Building - Home Maintenance, Cable, Contractin...
# 1  Automotive, Calibration, Electrical Systems, E...
# 2  Automotive, Automotive Parts, Cable, Electrica...
# 3                                   Outsourcing, Law
# 4  Private Label, Product Development, Production...
# 5
# 6
# 7                  Manufacturing Products - Services
# 8                                         Consulting
# 9
#
#                                             Location  \
# 0  1287 Marquette Street, 216-500-2029, Cleveland...
# 1  7015 Ordan Drive, 216-500-2030, Mississauga, O...
# 2  825-B, route 222, 216-500-2031, Maricourt, Que...
# 3  Lindora Corporate Center, 216-500-2032, San Jo...
# 4  trasnversal 93# 51-98 bog.47, 216-500-2033, Bo...
# 5  260-21320 Gordon Way, 216-500-2034, Richmond, ...
# 6  Atenas no. 56, 216-500-2035, Mexico, D.F., Dis...
# 7  695-2050, 216-500-2036, San Pedro, San José, 2050
# 8  1st Floor,Elizabeth House, 216-500-2037, Leeds...
# 9  Rua Plinio de Morais 422, 216-500-2038, Sao Pa...
#
#                                           References  \
# 0                 RWJ Wiring Inc., City of Cleveland
# 1  Honda, Tom O'donnell, Silgan Plastics, Robert ...
# 2  Bombardier Recreative Product 565 rue de la Mo...
# 3  Costa Rica Global Law Inc SA, CR Global Law is...
# 4  Dipsa’s mission is to be a positive force for ...
# 5  April Cimorelli Supplier Diversity Program Man...
# 6                                           ADD, ADD
# 7                                           ADD, ADD
# 8                                           BP, UKTI
# 9  We work for more then 10 years with clients li...
#
#                                        Scope of Work
# 0  Construction & Electrical Supplies, Electrical...
# 1  Worked in conjunction with their production fa...
# 2  We came up with a solution that satisfied both...
# 3  Business Legal Services in Costa Rica Legal do...
# 4  We differentiate our products by making them w...
# 5  We supply reusable, professional looking name ...
# 6                                           ADD, ADD
# 7                                           ADD, ADD
# 8  Corporate membership to connect female busines...
# 9  Digital communication Brand book Events, Event...
#
# [10 rows x 32 columns]

# %%
print(df.columns)
# Out:
# Index(['Prefix', 'First Name', 'Last Name', 'Primary Email', 'Secondary Email',
#        'Company', 'Job Title', 'Mobile Number', 'Number of Employees',
#        'Business Established Date', 'BBB Number', 'Business DUNS Number',
#        'RPO', 'Distribution Country', 'Manufactures Country', 'Ethnicity',
#        'Revenue', 'Business Tax Id', 'Website URL', 'Business Description',
#        'Geographical Region', 'Keywords', 'Business Structure', 'Fax Number',
#        'Non WBENC Awards', 'Outside Facilities', 'Business Category',
#        'NAICS Codes', 'Commodities', 'Location', 'References',
#        'Scope of Work'],
#       dtype='object')

# %%
reordered_cols = ['Prefix', 'First Name', 'Last Name', 'Primary Email', 'Secondary Email',
       'Job Title', 'Mobile Number', 'Company', 'Business Category',
       'NAICS Codes', 'Commodities', 'Location', 'Geographical Region', 'Number of Employees',
       'Business Established Date', 'BBB Number', 'Business DUNS Number',
       'RPO', 'Distribution Country', 'Manufactures Country', 'Ethnicity', 'References', 'Scope of Work',
       'Revenue', 'Business Tax Id', 'Website URL', 'Business Description',
       'Keywords', 'Business Structure', 'Fax Number', 'Non WBENC Awards', 'Outside Facilities']
df = df[reordered_cols]

# %%
df.to_csv('./data/Cleaned Seller data.csv')

# %%
# check null value removal 
initial_null = pd.read_csv('./data/Test MM  Seller data from wbenc.csv').isna().sum().sum()
cleaned_null = pd.read_csv('./data/Cleaned Seller data.csv').isna().sum().sum()
print(f'{initial_null} --> {cleaned_null}')
# Out:
# 8895 --> 2686
